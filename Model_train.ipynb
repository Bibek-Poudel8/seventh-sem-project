# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibek-Poudel8/seventh-sem-project/blob/bibek/Model_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
# !git clone https://github.com/Bibek-Poudel8/seventh-sem-project.git
# Out:
# Cloning into 'seventh-sem-project'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 86 (delta 10), reused 86 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 167.67 KiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls
# Out:
# sample_data  seventh-sem-project

# %%
# %cd seventh-sem-project
# Out:
# /content/seventh-sem-project

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git checkout bibek
# Out:
# Branch 'bibek' set up to track remote branch 'bibek' from 'origin'.
# Switched to a new branch 'bibek'

# %%
print ("Hello World")
# Out:
# Hello World

# %%
git add.
# Out:
#   File "/tmp/ipykernel_8912/3081662196.py", line 1
#     git add.
#         ^
# SyntaxError: invalid syntax
